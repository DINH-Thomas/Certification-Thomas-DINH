# %%
import pandas as pd
import sys

sys.path.insert(0, "../")
from src.training.train import prepare_data, train_log_model, save_artifacts
from src.training.evaluate import evaluate
from src.config.config import MODELS_DIR, LR_MODEL_PATH, VECTORIZER_PATH

# %%
df_cleaned = pd.read_csv("../data/cleaned/balanced_30k_dataset.csv")

# %%
X_train, y_train, X_val, y_val, X_test, y_test = prepare_data(df_cleaned)

# %%
vectorizer, lr_model = train_log_model(X_train, y_train)

# %%
evaluate(lr_model, vectorizer, X_test, y_test)

# %%
# Uncomment to save the model and vectorizer artifacts
"""
save_artifacts(vectorizer, lr_model,
               models_dir=MODELS_DIR,
               model_path=LR_MODEL_PATH,
               vectorizer_path=VECTORIZER_PATH)
"""
